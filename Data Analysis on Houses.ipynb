# %% [markdown]
# # **Dataset and Details**

# %%
import pandas as pd
file_path = '/content/train.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
df.nunique()
# Out:
# Id               1460
# MSSubClass         15
# MSZoning            5
# LotFrontage       110
# LotArea          1073
#                  ...
# MoSold             12
# YrSold              5
# SaleType            9
# SaleCondition       6
# SalePrice         663
# Length: 81, dtype: int64

# %% [markdown]
# # **Null values**

# %%
import numpy as np
columns_= df.columns[df.isna().any()].tolist()
Nan_value=pd.DataFrame(df[columns_].isna().sum(), columns=['Number of null values'])
Nan_value['Percentage']=np.round(100*Nan_value['Number of null values']/len(df),2)
Nan_value
# Out:
#               Number of null values  Percentage
# LotFrontage                     259       17.74
# Alley                          1369       93.77
# MasVnrType                        8        0.55
# MasVnrArea                        8        0.55
# BsmtQual                         37        2.53
# BsmtCond                         37        2.53
# BsmtExposure                     38        2.60
# BsmtFinType1                     37        2.53
# BsmtFinType2                     38        2.60
# Electrical                        1        0.07
# FireplaceQu                     690       47.26
# GarageType                       81        5.55
# GarageYrBlt                      81        5.55
# GarageFinish                     81        5.55
# GarageQual                       81        5.55
# GarageCond                       81        5.55
# PoolQC                         1453       99.52
# Fence                          1179       80.75
# MiscFeature                    1406       96.30

# %%
dropped_columns = ['MiscFeature', 'Fence', 'PoolQC', 'FireplaceQu']
df = df.drop(dropped_columns, axis = 1)
df.shape
# Out:
# (1460, 77)

# %% [markdown]
# # **What is The building class and why it is important?**
#
# The 'MSSubClass' is all about the building class. If we want to see how much it matters for our main goal, 'SalePrice,' we can check out the correlation coefficient. This number falls between -1 and 1, and it tells us how strong and which way the connection goes between these two things.

# %%
correlate = df['SalePrice'].corr(df['MSSubClass'])
print(correlate)
# Out:
# -0.08428413512659531

# %% [markdown]
# They don't really have much of a connection.

# %% [markdown]
# # **Shapiro-Wilk test**
# Tests whether a data sample has a Gaussian distribution.
#
# Null Hypothesis (H0): The sample adheres to a Gaussian distribution.
#
# Alternative Hypothesis (H1): The sample deviates from a Gaussian distribution.

# %%
from scipy.stats import shapiro

def shapiro_test(data):
    statistic, p_value = shapiro(data)
    print(f'Statistic: {statistic:.3f}')
    print(f'p-value: {p_value:.3f}')

# %%
cols_ = df['LotArea']
shapiro_test(cols_)
# Out:
# Statistic: 0.351
# p-value: 0.000

# %% [markdown]
# Because our p-value is below 0.05, we can totally declare that 'LotArea' ain't playing by the normal distribution rules.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

palette = sns.color_palette(n_colors=15, desat=1)
sns.histplot(data=df, x='LotArea', bins=15, palette=palette)
plt.title('LotArea', fontsize=10)
plt.show()
# Out:
# <ipython-input-115-d45de2fe13de>:5: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.histplot(data=df, x='LotArea', bins=15, palette=palette)

# %% [markdown]
# # **Anderson-Darling test**
# We've got a bunch of tests to see if our data is playing it cool with that normal distribution vibe. Right now, we're rolling with the Anderson-Darling test on 'overallQual'

# %%
from scipy.stats import anderson
temp = anderson(df['OverallQual'])
print(f"Test statistic: {temp.statistic:.3f}")
print(f"Critical values: {temp.critical_values}")
# Out:
# Test statistic: 35.230
# Critical values: [0.574 0.654 0.785 0.916 1.089]

# %%
import matplotlib.pyplot as plt
plt.hist(df['OverallQual'], bins=15 , color = 'white' , edgecolor = 'red')
plt.title('Overall Quality')
plt.show()

# %% [markdown]
# As you can see the test statistic is larger than any of the critical values, so the null hypothesis is rejected and  this feature ain't playing nice with a normal distribution.

# %%
temp = anderson(df['YearBuilt'])
print(f'Test statistic: {temp.statistic:.3f}')
print(f'Critical values: {temp.critical_values}')
# Out:
# Test statistic: 30.964
# Critical values: [0.574 0.654 0.785 0.916 1.089]

# %%
plt.hist(df['YearBuilt'],bins=10,color='white',edgecolor='red')
plt.title('YearBuilt',fontsize = 20)
plt.show()

# %%
temp = anderson(df['BedroomAbvGr'])
print('Test statistic: %.3f' % temp.statistic)
print('Critical values: %s' % temp.critical_values)
# Out:
# Test statistic: 106.548
# Critical values: [0.574 0.654 0.785 0.916 1.089]

# %%
plt.hist(df['BedroomAbvGr'],bins=10,color='white',edgecolor='red')
plt.title('Bedrooms above grade' , fontsize = 20)
plt.show()

# %% [markdown]
# # **Heat Maps**
# Correlation tests can help us determine whether a feature is related to our target or not,if yes how strong the relation is and in which direction.
# We can plot a heatmap which will illustrate the correlation between each pair of our selected features and our target column.We have to use heatmap, for understand the relation between each pair of the columns of the dataset.
# The color of each cell will show the strength of relation between pairs.

# %% [markdown]
# Numerical columns :

# %%
num_columns = df.select_dtypes(include=['int64', 'float64'])
correlation_mat = num_columns.corr()
fig, ax = plt.subplots(figsize=(30, 30))
sns.heatmap(correlation_mat, cmap='viridis', annot=True , linewidths=1.5, linecolor='blue', cbar=True, cbar_kws={'label': 'Correlation_matrix'} , ax=ax)
# Out:
# <Axes: >

# %% [markdown]
# We can use the solution below for solve heatmaps problem with object columns.

# %%
map_df = df.copy(deep=True)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for col in map_df.select_dtypes(include='object'):
    map_df[col] = le.fit_transform(df[col])

# %%
correlation_mat = df.corr()
fig, ax = plt.subplots(figsize=(25, 25))
sns.heatmap(correlation_mat , ax=ax )
# Out:
# <ipython-input-125-cbd9a5c1b611>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_mat = df.corr()
# <Axes: >

# %% [markdown]
# # **Analysis of Variance test**
#
# This test only works for numerical features; for categorical ones, we must try other methods. Here, we group our target column by the neighborhood's different values and then apply the ANOVA test.
#
# This test has two hypotheses:
#
# Null Hypothesis (H0): No statistically significant distinction exists in the means of the features under comparison.
#
# Alternative Hypothesis (H1): A statistically significant difference exists between the means.

# %%
ANOVA_df = df.copy(deep=True)

# %%
from scipy import stats
anova = ANOVA_df.groupby('Neighborhood')['SalePrice']
f_value , p_value = stats.f_oneway(*[group for name , group in anova])
print('f={0:.3f} , p={1:.3f}'.format(f_value,p_value))
# Out:
# f=71.785 , p=0.000

# %% [markdown]
# There is a significant difference between the means of two features,these two features are correlated.

# %%
anova = ANOVA_df.groupby('SaleCondition')['SalePrice']
f_value , p_value = stats.f_oneway(*[group for name , group in anova])
print('f={0:.3f} , p={1:.3f}'.format(f_value,p_value))
# Out:
# f=45.578 , p=0.000

# %% [markdown]
# Sale condition is related to sale price however of lower f-value,the relationship between them is less strong compared to Neighborhoof and Sale price.

# %% [markdown]
# # **Pearson test**
# Pearson's correlation test is one of the most used correlation test . Here we use it for some of the features.
#
# H0 :the samples are correlated.
#
# H1: the sample does not have any correlation.

# %%
print(df['SalePrice'].corr(df['MSSubClass']))
# Out:
# -0.08428413512659531

# %% [markdown]
# Tthey're poorly correlated.

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.scatter(df['MSSubClass'], df['SalePrice'])
ax.set_xlabel('MSSubClass')
ax.set_ylabel('SalePrice')
ax.set_title('MSSubClass vs SalePrice')
plt.show()

# %%
print(df['SalePrice'].corr(df['LotArea']))
# Out:
# 0.2638433538714057

# %%
import seaborn as sns
import pandas as pd
map_df = df[['LotArea', 'SalePrice']].copy()
sns.heatmap(map_df.corr(), annot=True, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# # **T-test**

# %% [markdown]
# We use t-test to figure out if two groups of data are different from each other or not and if they are , how significant this difference is.

# %%
from scipy.stats import ttest_ind
test_df = df.copy(deep=True)
t_statistic, p_value = ttest_ind(test_df['SalePrice'], test_df['2ndFlrSF'])
print('T-Statistic:', t_statistic)
print('P-Value:', p_value)
# Out:
# T-Statistic: 86.85056754216151
# P-Value: 0.0

# %% [markdown]
# This result makes us certain that there's a large difference between the means of the two columns we chose. Since the p-value is 0.0 we can conclude that this difference hasn't happened by chance.
